# %% [markdown]
# <a href="https://colab.research.google.com/github/merdweebner/Chrombot-server/blob/master/Copy_of_numpyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# acessing the second row of the rand_mat
rand_mat [1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-978a2be67161> in <cell line: 0>()
#       1 # acessing the second row of the rand_mat
# ----> 2 rand_mat [1]
#
# NameError: name 'rand_mat' is not defined

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

# Define the number of rows
num_rows = 1000000

# Define the possible values
states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking", "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

start_date = "2022-01-01"
end_date = "2022-12-31"
# Create a date range
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Adding issue weekday based on the "Issue Date"
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

# Grouping by issue_weekday and counting the Summons Number
df.groupby(["Issue Date"])["Ticket Number"
].count().sort_values()
# Out:
# /usr/local/lib/python3.11/dist-packages/cudf/utils/_ptxcompiler.py:64: UserWarning: Error getting driver and runtime versions:
#
# stdout:
#
#
#
# stderr:
#
# Traceback (most recent call last):
#   File "<string>", line 4, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/numba_cuda/numba/cuda/cudadrv/driver.py", line 314, in __getattr__
#     raise CudaSupportError("Error at driver init: \n%s:" %
# numba.cuda.cudadrv.error.CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
#
# Not patching Numba
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/cudf/utils/gpu_utils.py:62: UserWarning: Failed to dlopen libcuda.so.1
#   warnings.warn(str(e))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-fad75113b66a> in <cell line: 0>()
# ----> 1 get_ipython().run_line_magic('load_ext', 'cudf.pandas')
#       2 import pandas as pd
#       3 import numpy as np
#       4
#       5 import pandas as pd
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      85                               dir=compress_user(self.ipython_extension_dir)))
#      86             mod = sys.modules[module_str]
# ---> 87             if self._call_load_ipython_extension(mod):
#      88                 self.loaded.add(module_str)
#      89             else:
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/extensions.py in _call_load_ipython_extension(self, mod)
#     132     def _call_load_ipython_extension(self, mod):
#     133         if hasattr(mod, 'load_ipython_extension'):
# --> 134             mod.load_ipython_extension(self.shell)
#     135             return True
#     136
#
# /usr/local/lib/python3.11/dist-packages/cudf/pandas/magics.py in load_ipython_extension(ip)
#      25         from . import install
#      26
# ---> 27         install()
#      28         ip.register_magics(CudfPandasMagics)
#      29
#
# /usr/local/lib/python3.11/dist-packages/cudf/pandas/__init__.py in install()
#      48     # The default mode is "managed_pool" if UVM is supported, otherwise "pool"
#      49     managed_memory_is_supported = (
# ---> 50         pylibcudf.utils._is_concurrent_managed_access_supported()
#      51     )
#      52     default_rmm_mode = (
#
# utils.pyx in pylibcudf.utils._is_concurrent_managed_access_supported()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/runtime.pyx in cuda.bindings.runtime.cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/cyruntime.pyx in cuda.bindings.cyruntime.cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/cyruntime.pyx in cuda.bindings._lib.cyruntime.cyruntime._cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/utils.pyx in cuda.bindings._lib.cyruntime.utils.cudaPythonGlobal.lazyInitContextState()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/utils.pyx in cuda.bindings._lib.cyruntime.utils.cudaPythonGlobal.lazyInitDriver()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_bindings/cydriver.pyx in cuda.bindings._bindings.cydriver._cuInit()
#
# RuntimeError: Function "cuInit" not found

# %%
# printing the data type of lists
print("Data type of arr_str: ',type (np_arr_str))
print ('Data type of arr_num:',type(arr_numm))
# Out:
#   File "<ipython-input-5-2e1a1df56661>", line 2
#     print("Data type of arr_str: ',type (np_arr_str))
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# printing the data type after conversion of lists to array print (.Data type of np_arr_str,type(np_arr_str))

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %% [markdown]
# [link text](https://)

# %% [markdown]
# I.e. Midnight on the given date.

# %%
import pandas as pd

pd.Timestamp('9/27/22').tz_localize('US/Pacific')
# Out:
# Timestamp('2022-09-27 00:00:00-0700', tz='US/Pacific')

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Which parking violation is most commonly committed by vehicles from various U.S states?

(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)
# Out:
# /usr/local/lib/python3.11/dist-packages/cudf/utils/_ptxcompiler.py:64: UserWarning: Error getting driver and runtime versions:
#
# stdout:
#
#
#
# stderr:
#
# Traceback (most recent call last):
#   File "<string>", line 4, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/numba_cuda/numba/cuda/cudadrv/driver.py", line 314, in __getattr__
#     raise CudaSupportError("Error at driver init: \n%s:" %
# numba.cuda.cudadrv.error.CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
#
# Not patching Numba
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/cudf/utils/gpu_utils.py:62: UserWarning: Failed to dlopen libcuda.so.1
#   warnings.warn(str(e))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-d614f6eb7df8> in <cell line: 0>()
# ----> 1 get_ipython().run_line_magic('load_ext', 'cudf.pandas')
#       2 import pandas as pd
#       3 import numpy as np
#       4
#       5 # Randomly generated dataset of parking violations-
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      85                               dir=compress_user(self.ipython_extension_dir)))
#      86             mod = sys.modules[module_str]
# ---> 87             if self._call_load_ipython_extension(mod):
#      88                 self.loaded.add(module_str)
#      89             else:
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/extensions.py in _call_load_ipython_extension(self, mod)
#     132     def _call_load_ipython_extension(self, mod):
#     133         if hasattr(mod, 'load_ipython_extension'):
# --> 134             mod.load_ipython_extension(self.shell)
#     135             return True
#     136
#
# /usr/local/lib/python3.11/dist-packages/cudf/pandas/magics.py in load_ipython_extension(ip)
#      25         from . import install
#      26
# ---> 27         install()
#      28         ip.register_magics(CudfPandasMagics)
#      29
#
# /usr/local/lib/python3.11/dist-packages/cudf/pandas/__init__.py in install()
#      48     # The default mode is "managed_pool" if UVM is supported, otherwise "pool"
#      49     managed_memory_is_supported = (
# ---> 50         pylibcudf.utils._is_concurrent_managed_access_supported()
#      51     )
#      52     default_rmm_mode = (
#
# utils.pyx in pylibcudf.utils._is_concurrent_managed_access_supported()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/runtime.pyx in cuda.bindings.runtime.cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/cyruntime.pyx in cuda.bindings.cyruntime.cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/cyruntime.pyx in cuda.bindings._lib.cyruntime.cyruntime._cudaFree()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/utils.pyx in cuda.bindings._lib.cyruntime.utils.cudaPythonGlobal.lazyInitContextState()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_lib/cyruntime/utils.pyx in cuda.bindings._lib.cyruntime.utils.cudaPythonGlobal.lazyInitDriver()
#
# /usr/local/lib/python3.11/dist-packages/cuda/bindings/_bindings/cydriver.pyx in cuda.bindings._bindings.cydriver._cuInit()
#
# RuntimeError: Function "cuInit" not found

# %%
# @title Create a prompt

import google.generativeai as genai
from google.colab import userdata

api_key_name = 'GOOGLE_API_KEY' # @param {type: "string"}
prompt = 'What is the velocity of an unladen swallow?' # @param {type: "string"}
system_instructions = 'You have a tendency to speak in riddles.' # @param {type: "string"}
model = 'gemini-2.0-flash' # @param {type: "string"} ["gemini-1.0-pro", "gemini-1.5-pro", "gemini-1.5-flash", "gemini-2.0-flash"]
temperature = 0.5 # @param {type: "slider", min: 0, max: 2, step: 0.05}
stop_sequence = '' # @param {type: "string"}

if model == 'gemini-1.0-pro' and system_instructions is not None:
  system_instructions = None
  print('\x1b[31m(WARNING: System instructions ignored, gemini-1.0-pro does not support system instructions)\x1b[0m')

if model == 'gemini-1.0-pro' and temperature > 1:
  temperature = 1
  print('\x1b[34m(INFO: Temperature set to 1, gemini-1.0-pro does not support temperature > 1)\x1b[0m')

if system_instructions == '':
  system_instructions = None

api_key = userdata.get(api_key_name)
genai.configure(api_key=api_key)
model = genai.GenerativeModel(model, system_instruction=system_instructions)
config = genai.GenerationConfig(temperature=temperature, stop_sequences=[stop_sequence])
response = model.generate_content(contents=[prompt], generation_config=config)
response.text
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-4c15e1efbefe> in <cell line: 0>()
#      22   system_instructions = None
#      23
# ---> 24 api_key = userdata.get(api_key_name)
#      25 genai.configure(api_key=api_key)
#      26 model = genai.GenerativeModel(model, system_instruction=system_instructions)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      60   # thread-safe.
#      61   with _userdata_lock:
# ---> 62     resp = _message.blocking_request(
#      63         'GetSecret', request={'key': key}, timeout_sec=10
#      64     )
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: User secrets cannot be accessed in agent mode. Learn more at https://research.google.com/colaboratory/faq.html#data-science-agent.

# %%
import ipywidgets as widgets

slider = widgets.IntSlider(20, min=0, max=100)
slider
# Out:
# IntSlider(value=20)

# %%
import altair as alt
import ipywidgets as widgets
from vega_datasets import data

source = data.stocks()

stock_picker = widgets.SelectMultiple(
    options=source.symbol.unique(),
    value=list(source.symbol.unique()),
    description='Symbols')

# The value of symbols will come from the stock_picker.
@widgets.interact(symbols=stock_picker)
def render(symbols):
  selected = source[source.symbol.isin(list(symbols))]

  return alt.Chart(selected).mark_line().encode(
      x='date',
      y='price',
      color='symbol',
      strokeDash='symbol',
  )
# Out:
# interactive(children=(SelectMultiple(description='Symbols', index=(0, 1, 2, 3, 4), options=('MSFT', 'AMZN', 'I…

# %%
import IPython
from google.colab import output

def Concat(a, b):
  # Use display.JSON to transfer a structured result.
  return IPython.display.JSON({'result': ' '.join((a, b))})

output.register_callback('notebook.Concat', Concat)

# %%
# %%javascript
# (async function() {
#   const result = await google.colab.kernel.invokeFunction(
#     'notebook.Concat', // The callback name.
#     ['hello', 'world!'], // The arguments.
#     {}); // kwargs
#   const text = result.data['application/json'];
#   document.querySelector("#output-area").appendChild(document.createTextNode(text.result));
# })();

# %%
import IPython
from google.colab import output

display(IPython.display.HTML('''
    The items:
    <br><ol id="items"></ol>
    <button id='button'>Click to add</button>
    <script>
      document.querySelector('#button').onclick = () => {
        google.colab.kernel.invokeFunction('notebook.AddListItem', [], {});
      };
    </script>
    '''))

def add_list_item():
  # Use redirect_to_element to direct the elements which are being written.
  with output.redirect_to_element('#items'):
    # Use display to add items which will be persisted on notebook reload.
    display(IPython.display.HTML('<li> Another item</li>'))

output.register_callback('notebook.AddListItem', add_list_item)

# %%
import IPython
import uuid
from google.colab import output

class InvokeButton(object):
  def __init__(self, title, callback):
    self._title = title
    self._callback = callback

  def _repr_html_(self):
    callback_id = 'button-' + str(uuid.uuid4())
    output.register_callback(callback_id, self._callback)

    template = """<button id="{callback_id}">{title}</button>
        <script>
          document.querySelector("#{callback_id}").onclick = (e) => {{
            google.colab.kernel.invokeFunction('{callback_id}', [], {{}})
            e.preventDefault();
          }};
        </script>"""
    html = template.format(title=self._title, callback_id=callback_id)
    return html

def do_something():
  print('here')

InvokeButton('click me', do_something)

# %% [markdown]
# 1.   List item
# 2.   List item
#
#
#
# ```
# # This is formatted as code
# ```
#
#
#
# ```
# # This is formatted as code
# ```

# %%
from google. colab import drive
drive.mount('/content/drive')
{} # creating a random matries randint-matrix1 = np.random.randint (1,10,10).
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {}

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-11-ee60fe07601b> in <cell line: 0>()
#       1 import ee
#       2 import geemap
# ----> 3 ee.Initialize()
#       4 m = geemap.Map()
#       5
#
# /usr/local/lib/python3.11/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/ee/__init__.py in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     183   """
#     184   if credentials == 'persistent':
# --> 185     credentials = data.get_persistent_credentials()
#     186   if not project and credentials and hasattr(credentials, 'quota_project_id'):
#     187     project = credentials.quota_project_id
#
# /usr/local/lib/python3.11/dist-packages/ee/data.py in get_persistent_credentials()
#     279     if oauth.is_valid_credentials(credentials):
#     280       return credentials
# --> 281   raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     282       'Please authorize access to your Earth Engine account by '
#     283       'running\n\nearthengine authenticate\n\n'
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
#
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# I.e. Midnight on the given date.

# %%
import pandas as pd

pd.Timestamp('9/27/22').tz_localize('US/Pacific')

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-12-ee60fe07601b> in <cell line: 0>()
#       1 import ee
#       2 import geemap
# ----> 3 ee.Initialize()
#       4 m = geemap.Map()
#       5
#
# /usr/local/lib/python3.11/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/ee/__init__.py in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     183   """
#     184   if credentials == 'persistent':
# --> 185     credentials = data.get_persistent_credentials()
#     186   if not project and credentials and hasattr(credentials, 'quota_project_id'):
#     187     project = credentials.quota_project_id
#
# /usr/local/lib/python3.11/dist-packages/ee/data.py in get_persistent_credentials()
#     279     if oauth.is_valid_credentials(credentials):
#     280       return credentials
# --> 281   raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     282       'Please authorize access to your Earth Engine account by '
#     283       'running\n\nearthengine authenticate\n\n'
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)

points + lines

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)

points + lines

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)

points + lines

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)

points + lines
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# alt.LayerChart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)

points + lines
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# alt.LayerChart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# alt.Chart(...)

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-8-ee60fe07601b> in <cell line: 0>()
#       1 import ee
#       2 import geemap
# ----> 3 ee.Initialize()
#       4 m = geemap.Map()
#       5
#
# /usr/local/lib/python3.11/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/ee/__init__.py in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     183   """
#     184   if credentials == 'persistent':
# --> 185     credentials = data.get_persistent_credentials()
#     186   if not project and credentials and hasattr(credentials, 'quota_project_id'):
#     187     project = credentials.quota_project_id
#
# /usr/local/lib/python3.11/dist-packages/ee/data.py in get_persistent_credentials()
#     279     if oauth.is_valid_credentials(credentials):
#     280       return credentials
# --> 281   raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     282       'Please authorize access to your Earth Engine account by '
#     283       'running\n\nearthengine authenticate\n\n'
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.

# %% [markdown]
# I.e. Midnight on the given date.

# %% [markdown]
# I.e. Midnight on the given date.

# %% [markdown]
# I.e. Midnight on the given date.

# %%
import pandas as pd

pd.Timestamp('9/27/22').tz_localize('US/Pacific')
# Out:
# Timestamp('2022-09-27 00:00:00-0700', tz='US/Pacific')

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

import matplotlib.pyplot as plt

# Data import and filtering
modis_collection = ee.ImageCollection(
    'MODIS/061/MCD12Q1').filterDate('2019-01-01', '2020-01-01')

country = ee.FeatureCollection('WM/geoLab/geoBoundaries/600/ADM0').filter(
    ee.Filter.equals('shapeName', 'Suriname'))

land_cover_image = modis_collection.select('LC_Type1').first().clip(country)

land_cover_classes = ee.List.sequence(1, 17) # Assuming 17 land cover classes

def calculate_area(class_value):
  class_mask = land_cover_image.eq(ee.Number(class_value).toInt())
  class_area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
    reducer=ee.Reducer.sum(),
    geometry=country,
    scale=500,
    maxPixels=1e13
    ).get('LC_Type1')
  return ee.Feature(
    None, {'class_value': class_value, 'class_area': class_area})

area_results = ee.FeatureCollection(land_cover_classes.map(calculate_area))
df = ee.data.computeFeatures(
{'expression': area_results, 'fileFormat': 'PANDAS_DATAFRAME'})

# Create bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['class_value'], df['class_area'])
plt.xlabel('Land Cover Class')
plt.ylabel('Area (square meters)')
plt.title('Area of MODIS Land Cover Classes in Suriname (2019)')

# Set x-ticks to be integers and show all classes
plt.xticks(df['class_value'], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

pd.Timestamp('9/27/22').tz_localize('US/Pacific')
# Out:
# Timestamp('2022-09-27 00:00:00-0700', tz='US/Pacific')

# %%
import pandas as pd

pd.Timestamp('9/27/22').tz_localize('US/Pacific')

# %%
# generating random values in an array
rand_mat = np.random.rand (5)
print (rand_mat)

# %% [markdown]
# # Task
# How do I filter a Pandas DataFrame?
#
# Here is all the data you need:
# "foodhub_orderds(in) - Copy.xlsx"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the Excel file "foodhub_orderds(in) - Copy.xlsx" into a Pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the Excel file into a pandas DataFrame and display some information about it.

# %%
import pandas as pd

try:
    df = pd.read_excel('foodhub_orderds(in) - Copy.xlsx')
    display(df.head())
    print(f"Shape of the DataFrame: {df.shape}")
    print(f"Columns of the DataFrame: {df.columns}")
except FileNotFoundError:
    print("Error: File not found. Please make sure the file path is correct.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    order_id  customer_id    restaurant_name cuisine_type  cost_of_the_order  \
# 0   1476547        83095         Bareburger     American               6.84
# 1   1476548       122609  Blue Ribbon Sushi     Japanese               6.84
# 2   1476549        75169   Tamarind TriBeCa       Indian               6.74
# 3   1476550       101347           The Loop     Japanese              16.98
# 4   1476551        49034          The Smile     American              12.18
#
#   day_of_the_week     rating  food_preparation_time  delivery_time
# 0         Weekend          5                     22             24
# 1         Weekend          4                     20             30
# 2         Weekend          5                     25             26
# 3         Weekend          5                     26             27
# 4         Weekend  Not given                     22             27
# Shape of the DataFrame: (1898, 9)
# Columns of the DataFrame: Index(['order_id', 'customer_id', 'restaurant_name', 'cuisine_type',
#        'cost_of_the_order', 'day_of_the_week', 'rating',
#        'food_preparation_time', 'delivery_time'],
#       dtype='object')

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded DataFrame (`df`) to understand its structure and identify relevant columns for filtering.

# %% [markdown]
# **Reasoning**:
# Examine the data types, missing values, descriptive statistics, unique values, and data shape to understand the structure of the DataFrame.

# %%
# Examine Data Types
print("Data Types:\n", df.dtypes)

# Identify Missing Values
print("\nMissing Values:\n", df.isnull().sum())

# Descriptive Statistics for Numerical Columns
print("\nDescriptive Statistics:\n", df.describe())

# Unique Values in Categorical Columns
for col in ['restaurant_name', 'cuisine_type', 'day_of_the_week']:
    print(f"\nUnique values in {col}:\n{df[col].value_counts()}")

# Data Shape and Column Names (already done in previous step, but included here for completeness)
print(f"\nShape of the DataFrame: {df.shape}")
print(f"\nColumns of the DataFrame: {df.columns}")
# Out:
# Data Types:
#  order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object
#
# Missing Values:
#  order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64
#
# Descriptive Statistics:
#             order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000
#
# Unique values in restaurant_name:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
#                             ...
# Galli Restaurant               1
# Il Bambino                     1
# Cafe de La Esquina             1
# Samurai Mama                   1
# Dig Inn Seasonal Market        1
# Name: count, Length: 178, dtype: int64
#
# Unique values in cuisine_type:
# cuisine_type
# American          584
# Japanese          470
# Italian           298
# Chinese           215
# Mexican            77
# Indian             73
# Middle Eastern     49
# Mediterranean      46
# Thai               19
# French             18
# Southern           17
# Korean             13
# Spanish            12
# Vietnamese          7
# Name: count, dtype: int64
#
# Unique values in day_of_the_week:
# day_of_the_week
# Weekend    1351
# Weekday     547
# Name: count, dtype: int64
#
# Shape of the DataFrame: (1898, 9)
#
# Columns of the DataFrame: Index(['order_id', 'customer_id', 'restaurant_name', 'cuisine_type',
#        'cost_of_the_order', 'day_of_the_week', 'rating',
#        'food_preparation_time', 'delivery_time'],
#       dtype='object')

# %% [markdown]
# ## Data preparation
#
# ### Subtask:
# Prepare the data for filtering operations by handling any inconsistencies or potential issues that might affect the filtering process.

# %% [markdown]
# **Reasoning**:
# Check for duplicate rows, verify data types, and handle inconsistent values in the dataframe.

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
if not duplicate_rows.empty:
    print("Duplicate rows found:")
    display(duplicate_rows)
    # Decision: Remove duplicate rows. Rationale: Duplicate rows can skew analysis and filtering.
    df_no_duplicates = df.drop_duplicates()
    print("Duplicate rows removed. New DataFrame shape:", df_no_duplicates.shape)
else:
    print("No duplicate rows found.")
    df_no_duplicates = df
    print("Continuing with original DataFrame.")

# Verify data types and handle inconsistencies
print("\nData types before conversion:")
display(df_no_duplicates.dtypes)

# Check for inconsistencies in categorical columns
for col in ['restaurant_name', 'cuisine_type', 'day_of_the_week']:
    print(f"\nUnique values in {col}:\n{df_no_duplicates[col].value_counts()}")

# No obvious inconsistencies found in categorical columns.

# Convert data types if necessary (based on previous exploration, no conversions are needed)
# Example of a type conversion (uncomment if necessary)
# df_no_duplicates['cost_of_the_order'] = pd.to_numeric(df_no_duplicates['cost_of_the_order'], errors='coerce')

print("\nData types after conversion (if any):")
display(df_no_duplicates.dtypes)
# Out:
# No duplicate rows found.
# Continuing with original DataFrame.
#
# Data types before conversion:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object
# Unique values in restaurant_name:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
#                             ...
# Galli Restaurant               1
# Il Bambino                     1
# Cafe de La Esquina             1
# Samurai Mama                   1
# Dig Inn Seasonal Market        1
# Name: count, Length: 178, dtype: int64
#
# Unique values in cuisine_type:
# cuisine_type
# American          584
# Japanese          470
# Italian           298
# Chinese           215
# Mexican            77
# Indian             73
# Middle Eastern     49
# Mediterranean      46
# Thai               19
# French             18
# Southern           17
# Korean             13
# Spanish            12
# Vietnamese          7
# Name: count, dtype: int64
#
# Unique values in day_of_the_week:
# day_of_the_week
# Weekend    1351
# Weekday     547
# Name: count, dtype: int64
#
# Data types after conversion (if any):
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object

# %% [markdown]
# ## Data wrangling
#
# ### Subtask:
# Demonstrate various filtering techniques on the prepared DataFrame `df_no_duplicates`.

# %% [markdown]
# **Reasoning**:
# Perform all the filtering operations as instructed, using the provided DataFrame `df_no_duplicates`.

# %%
# 1. Filtering by a single column with a specific value
burger_king_orders = df_no_duplicates[df_no_duplicates['restaurant_name'] == 'Burger King']
print("Burger King Orders Shape:", burger_king_orders.shape)
display(burger_king_orders.head())

# 2. Filtering by multiple conditions
expensive_weekend_orders = df_no_duplicates[(df_no_duplicates['cost_of_the_order'] > 20) & (df_no_duplicates['day_of_the_week'] == 'Weekend')]
print("\nExpensive Weekend Orders Shape:", expensive_weekend_orders.shape)
display(expensive_weekend_orders.head())

# 3. Filtering using string methods
indian_cuisine_orders = df_no_duplicates[df_no_duplicates['cuisine_type'].str.contains('Indian', case=False, na=False)]
print("\nIndian Cuisine Orders Shape:", indian_cuisine_orders.shape)
display(indian_cuisine_orders.head())

# 4. Filtering using numerical comparisons
fast_food_orders = df_no_duplicates[df_no_duplicates['food_preparation_time'] < 20]
print("\nFast Food Orders Shape:", fast_food_orders.shape)
display(fast_food_orders.head())

# 5. Filtering with .loc
specific_rows_cols = df_no_duplicates.loc[10:20, ['order_id', 'cost_of_the_order', 'restaurant_name']]
print("\nSpecific Rows and Columns Shape:", specific_rows_cols.shape)
display(specific_rows_cols.head())

# 6. Filtering with .iloc
first_rows_cols = df_no_duplicates.iloc[0:5, 0:3]
print("\nFirst Rows and Columns Shape:", first_rows_cols.shape)
display(first_rows_cols.head())
# Out:
# Burger King Orders Shape: (0, 9)
# Empty DataFrame
# Columns: [order_id, customer_id, restaurant_name, cuisine_type, cost_of_the_order, day_of_the_week, rating, food_preparation_time, delivery_time]
# Index: []
# Expensive Weekend Orders Shape: (397, 9)
#     order_id  customer_id              restaurant_name cuisine_type  \
# 13   1476560       149508                  Shake Shack     American
# 17   1476564        83287  Five Guys Burgers and Fries     American
# 24   1476571       334758                    Melt Shop     American
# 27   1476574       376993                      Emporio      Italian
# 28   1476575       141912                P.J. Clarke's     American
#
#     cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 13              22.26         Weekend          4                     32
# 17              24.30         Weekend          5                     30
# 24              29.15         Weekend          4                     26
# 27              31.43         Weekend  Not given                     25
# 28              31.38         Weekend  Not given                     31
#
#     delivery_time
# 13             17
# 17             20
# 24             17
# 27             29
# 28             23
# Indian Cuisine Orders Shape: (73, 9)
#     order_id  customer_id           restaurant_name cuisine_type  \
# 2    1476549        75169          Tamarind TriBeCa       Indian
# 14   1476561       115213          Tamarind TriBeCa       Indian
# 23   1476570       148459     The Kati Roll Company       Indian
# 26   1476573       370405  Haveli Indian Restaurant       Indian
# 43   1476590       342107     The Kati Roll Company       Indian
#
#     cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 2                6.74         Weekend          5                     25
# 14              13.24         Weekend  Not given                     23
# 23               5.87         Weekday  Not given                     26
# 26              29.10         Weekday          3                     23
# 43              16.83         Weekend          4                     26
#
#     delivery_time
# 2              26
# 14             30
# 23             30
# 26             24
# 43             20
# Fast Food Orders Shape: (0, 9)
# Empty DataFrame
# Columns: [order_id, customer_id, restaurant_name, cuisine_type, cost_of_the_order, day_of_the_week, rating, food_preparation_time, delivery_time]
# Index: []
# Specific Rows and Columns Shape: (11, 3)
#     order_id  cost_of_the_order           restaurant_name
# 10   1476557              16.15     Otto Enoteca Pizzeria
# 11   1476558              16.10  Yama Japanese Restaurant
# 12   1476559              15.57                Bareburger
# 13   1476560              22.26               Shake Shack
# 14   1476561              13.24          Tamarind TriBeCa
# First Rows and Columns Shape: (5, 3)
#    order_id  customer_id    restaurant_name
# 0   1476547        83095         Bareburger
# 1   1476548       122609  Blue Ribbon Sushi
# 2   1476549        75169   Tamarind TriBeCa
# 3   1476550       101347           The Loop
# 4   1476551        49034          The Smile

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize the impact of one of the filtering operations performed in the previous step.

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of 'cost_of_the_order' for expensive weekend orders using a histogram.

# %%
import matplotlib.pyplot as plt

# Create a histogram of 'cost_of_the_order' for expensive weekend orders
plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
plt.hist(expensive_weekend_orders['cost_of_the_order'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Order Costs for Expensive Weekend Orders')
plt.xlabel('Cost of the Order')
plt.ylabel('Number of Orders')
plt.grid(axis='y', alpha=0.75)  # Add gridlines for better readability
plt.show()

# %% [markdown]
# ## Summary:
#
# ### 1. Q&A
# How do I filter a Pandas DataFrame?
#
# The provided code demonstrates several ways to filter a Pandas DataFrame:
#
# * **Filtering by a single column with a specific value:**  `df[df['restaurant_name'] == 'Burger King']`
# * **Filtering by multiple conditions:** `df[(df['cost_of_the_order'] > 20) & (df['day_of_the_week'] == 'Weekend')]`
# * **Filtering using string methods:** `df[df['cuisine_type'].str.contains('Indian', case=False, na=False)]`
# * **Filtering using numerical comparisons:** `df[df['food_preparation_time'] < 20]`
# * **Filtering with `.loc`:**  Selecting specific rows and columns by label.
# * **Filtering with `.iloc`:** Selecting specific rows and columns by integer position.
#
#
# ### 2. Data Analysis Key Findings
# * **No Duplicate Rows:** The dataset contained no duplicate rows.
# * **Expensive Weekend Orders:** 397 orders were identified as expensive (cost > $20) and placed on weekends.  A histogram of the order cost for this subset of the data was generated to visualize the distribution of costs.
# * **Indian Cuisine Orders:** 73 orders were identified as having an Indian cuisine type.
# * **Missing Burger King Orders:** No orders from Burger King were found in the dataset.
# * **No Fast Food Orders (based on the criteria used):** No orders with food preparation time less than 20 minutes were found.
#
#
# ### 3. Insights or Next Steps
# * **Investigate missing Burger King orders:**  The absence of Burger King orders is noteworthy.  Further investigation is needed to determine if this is due to data entry errors, a genuine lack of Burger King orders in the dataset, or other issues.
# * **Analyze the distribution of order costs:** The histogram of order costs for expensive weekend orders provides a visual representation of the data.  Further analysis of the distribution (e.g., using descriptive statistics or more advanced visualizations) might reveal additional insights into customer spending behavior on weekends.
